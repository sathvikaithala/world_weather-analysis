# %% [markdown]
# # Weather Database
# UC Berkeley Extension Data Analytics Boot Camp Module 6 Challenge - Part 1
#
# ## Part 1 Instructions
# #### Get the Weather Description and Amount of Precipitation for Each City

# %% [markdown]
# ### Collect the Data
# #### Use the NumPy module to generate more than 1,500 random latitudes and longitudes.

# %%
# Import Dependencies:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs) # packs each lat/lng pair into a tuple based on shared index

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Use the citipy module to list the nearest city to the latitudes and longitudes.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count (>500).
print(f"There are {len(cities)} cities in our database")
# Out:
# There are 605 cities in our database

# %% [markdown]
# #### Collect the following data from the JSON file and add it to a DataFrame:
#     - City, country, and date
#     - Latitude and longitude
#     - Maximum temperature
#     - Humidity
#     - Cloudiness
#     - Wind speed
#     - Weather Condition
#     - Snowfall (last 1 hr) - default to 0 if info is missing
#     - Rainfall (last 1 hr) - default to 0 if info is missing

# %%
# import the requests library
import requests

# import the API key from the config file
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# for farenheit, use units=imperial
# for celsius, use units=metric
# no units described will output in Kelvin

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# get a list that processes every name for validity (use try-except block)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        ### CHALLENGE:
        
        try:
            city_snow_1h = city_weather["snow"]["1h"]
        except KeyError: 
            city_snow_1h = 0
            
        try:
            city_rain_1h = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_1h = 0
            
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_desc,
                          "Snow (in)":city_snow_1h,
                          "Rain (in)":city_rain_1h,
                          "Country": city_country,
                          "Date": city_date})

#Use multiple try-except blocks to get the amount of rainfall and snowfall. 
#In the except block handle the KeyError if there is no rainfall or snowfall and add 0 inches for the amount.        
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katha
# City not found. Skipping...
# Processing Record 2 of Set 1 | deputatskiy
# Processing Record 3 of Set 1 | ranong
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | kazachinskoye
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | bondo
# Processing Record 13 of Set 1 | tigil
# Processing Record 14 of Set 1 | hervey bay
# Processing Record 15 of Set 1 | kozhevnikovo
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | karacabey
# Processing Record 20 of Set 1 | quatre cocos
# Processing Record 21 of Set 1 | margate
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | dorogobuzh
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | ahipara
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | krasnoselkup
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | batemans bay
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | misratah
# Processing Record 41 of Set 1 | cuauhtemoc
# Processing Record 42 of Set 1 | taoudenni
# Processing Record 43 of Set 1 | dunmore town
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | harper
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | chifeng
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | venado tuerto
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | camacha
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | talnakh
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | amarante do maranhao
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | manggar
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | asyut
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | hami
# Processing Record 24 of Set 2 | toccoa
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | rio gallegos
# Processing Record 27 of Set 2 | yumen
# Processing Record 28 of Set 2 | manzhouli
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | coihaique
# Processing Record 31 of Set 2 | nyurba
# Processing Record 32 of Set 2 | jos
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | kununurra
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | blacksburg
# Processing Record 39 of Set 2 | kahului
# Processing Record 40 of Set 2 | sioux lookout
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | aracaju
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | lata
# Processing Record 45 of Set 2 | mitsamiouli
# Processing Record 46 of Set 2 | qui nhon
# Processing Record 47 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | horodnytsya
# Processing Record 50 of Set 2 | karratha
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | soria
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | thinadhoo
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 3 | zyryanskoye
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | isla vista
# Processing Record 12 of Set 3 | kudat
# Processing Record 13 of Set 3 | bukama
# Processing Record 14 of Set 3 | xuddur
# Processing Record 15 of Set 3 | ormara
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | coswig
# Processing Record 18 of Set 3 | sistranda
# Processing Record 19 of Set 3 | grong
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | kautokeino
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | clyde river
# Processing Record 24 of Set 3 | jinka
# Processing Record 25 of Set 3 | russell
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | oyama
# Processing Record 29 of Set 3 | batsfjord
# Processing Record 30 of Set 3 | nakamura
# Processing Record 31 of Set 3 | temyasovo
# Processing Record 32 of Set 3 | lasa
# Processing Record 33 of Set 3 | soyo
# Processing Record 34 of Set 3 | san pedro pinula
# Processing Record 35 of Set 3 | pradopolis
# Processing Record 36 of Set 3 | port blair
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | bandarbeyla
# Processing Record 39 of Set 3 | moorhead
# Processing Record 40 of Set 3 | aksu
# Processing Record 41 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 3 | mecca
# Processing Record 43 of Set 3 | takoradi
# Processing Record 44 of Set 3 | carutapera
# Processing Record 45 of Set 3 | labuhan
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | senno
# Processing Record 1 of Set 4 | gimbi
# Processing Record 2 of Set 4 | xuanzhou
# Processing Record 3 of Set 4 | srednekolymsk
# Processing Record 4 of Set 4 | grindavik
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 4 | ladario
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | sao joao da barra
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | paraiso
# Processing Record 14 of Set 4 | college
# Processing Record 15 of Set 4 | okhotsk
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | port macquarie
# Processing Record 20 of Set 4 | herat
# Processing Record 21 of Set 4 | porto novo
# Processing Record 22 of Set 4 | fort nelson
# Processing Record 23 of Set 4 | la ronge
# Processing Record 24 of Set 4 | constitucion
# Processing Record 25 of Set 4 | tessalit
# Processing Record 26 of Set 4 | kjollefjord
# Processing Record 27 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | cam ranh
# Processing Record 30 of Set 4 | hobart
# Processing Record 31 of Set 4 | tarko-sale
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | vung tau
# Processing Record 34 of Set 4 | toppenish
# Processing Record 35 of Set 4 | beloha
# Processing Record 36 of Set 4 | kamaishi
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | avarua
# Processing Record 39 of Set 4 | poplar bluff
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | banyo
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | pemangkat
# Processing Record 44 of Set 4 | shamary
# Processing Record 45 of Set 4 | daru
# Processing Record 46 of Set 4 | yaviza
# Processing Record 47 of Set 4 | samana
# Processing Record 48 of Set 4 | tuatapere
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | lufilufi
# Processing Record 1 of Set 5 | bathsheba
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | kirakira
# Processing Record 5 of Set 5 | tevaitoa
# Processing Record 6 of Set 5 | uray
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | san jeronimo
# Processing Record 9 of Set 5 | vao
# Processing Record 10 of Set 5 | zhicheng
# Processing Record 11 of Set 5 | bend
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | silleda
# Processing Record 15 of Set 5 | plettenberg bay
# Processing Record 16 of Set 5 | bata
# Processing Record 17 of Set 5 | broken hill
# Processing Record 18 of Set 5 | callaway
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | vila franca do campo
# Processing Record 21 of Set 5 | ahuimanu
# Processing Record 22 of Set 5 | igarka
# Processing Record 23 of Set 5 | bonthe
# Processing Record 24 of Set 5 | ekhabi
# Processing Record 25 of Set 5 | alice springs
# Processing Record 26 of Set 5 | tautira
# Processing Record 27 of Set 5 | idrinskoye
# Processing Record 28 of Set 5 | bergen
# Processing Record 29 of Set 5 | strezhevoy
# Processing Record 30 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | puerto baquerizo moreno
# Processing Record 34 of Set 5 | atar
# Processing Record 35 of Set 5 | nouakchott
# Processing Record 36 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 5 | barcelona
# Processing Record 38 of Set 5 | vanimo
# Processing Record 39 of Set 5 | mackay
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | walvis bay
# Processing Record 42 of Set 5 | bayan
# Processing Record 43 of Set 5 | santa maria
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | rongcheng
# Processing Record 46 of Set 5 | mingaora
# Processing Record 47 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | hovd
# Processing Record 50 of Set 5 | roald
# Processing Record 1 of Set 6 | arlit
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | ushibuka
# Processing Record 4 of Set 6 | durazno
# Processing Record 5 of Set 6 | tayuman
# Processing Record 6 of Set 6 | freeport
# Processing Record 7 of Set 6 | henties bay
# Processing Record 8 of Set 6 | esna
# Processing Record 9 of Set 6 | logan lake
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | almaznyy
# Processing Record 12 of Set 6 | belmonte
# Processing Record 13 of Set 6 | pacific grove
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | esfarayen
# Processing Record 16 of Set 6 | ypsilanti
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | north highlands
# Processing Record 19 of Set 6 | lakselv
# Processing Record 20 of Set 6 | malanje
# Processing Record 21 of Set 6 | magole
# Processing Record 22 of Set 6 | yerbogachen
# Processing Record 23 of Set 6 | mehamn
# Processing Record 24 of Set 6 | caxito
# Processing Record 25 of Set 6 | temba
# Processing Record 26 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 27 of Set 6 | victoria
# Processing Record 28 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 6 | andreapol
# Processing Record 30 of Set 6 | kamenka
# Processing Record 31 of Set 6 | kupang
# Processing Record 32 of Set 6 | olinda
# Processing Record 33 of Set 6 | denpasar
# Processing Record 34 of Set 6 | hastings
# Processing Record 35 of Set 6 | san andres
# Processing Record 36 of Set 6 | vanino
# Processing Record 37 of Set 6 | esperance
# Processing Record 38 of Set 6 | kalanguy
# Processing Record 39 of Set 6 | kyshtovka
# Processing Record 40 of Set 6 | miles city
# Processing Record 41 of Set 6 | escanaba
# Processing Record 42 of Set 6 | baruun-urt
# Processing Record 43 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 6 | honiara
# Processing Record 45 of Set 6 | danville
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | baglan
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | kaitangata
# Processing Record 1 of Set 7 | puerto padre
# Processing Record 2 of Set 7 | palasa
# Processing Record 3 of Set 7 | itarema
# Processing Record 4 of Set 7 | mayo
# Processing Record 5 of Set 7 | mumford
# Processing Record 6 of Set 7 | pevek
# Processing Record 7 of Set 7 | fernley
# Processing Record 8 of Set 7 | koumac
# Processing Record 9 of Set 7 | vejalpur
# Processing Record 10 of Set 7 | aneho
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | roebourne
# Processing Record 13 of Set 7 | dokshukino
# City not found. Skipping...
# Processing Record 14 of Set 7 | sinnamary
# Processing Record 15 of Set 7 | chunskiy
# Processing Record 16 of Set 7 | wote
# Processing Record 17 of Set 7 | zeya
# Processing Record 18 of Set 7 | lavrentiya
# Processing Record 19 of Set 7 | saint-francois
# Processing Record 20 of Set 7 | mahibadhoo
# Processing Record 21 of Set 7 | baffa
# Processing Record 22 of Set 7 | tsumeb
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | canby
# Processing Record 25 of Set 7 | erice
# Processing Record 26 of Set 7 | brejinho
# Processing Record 27 of Set 7 | goalpara
# Processing Record 28 of Set 7 | marsabit
# Processing Record 29 of Set 7 | capela do alto
# Processing Record 30 of Set 7 | upernavik
# Processing Record 31 of Set 7 | baiyin
# Processing Record 32 of Set 7 | tyup
# Processing Record 33 of Set 7 | keti bandar
# Processing Record 34 of Set 7 | kavaratti
# Processing Record 35 of Set 7 | comodoro rivadavia
# Processing Record 36 of Set 7 | poya
# Processing Record 37 of Set 7 | superior
# Processing Record 38 of Set 7 | calbuco
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | lakes entrance
# Processing Record 41 of Set 7 | madera
# Processing Record 42 of Set 7 | viedma
# Processing Record 43 of Set 7 | codrington
# Processing Record 44 of Set 7 | bahadurgarh
# Processing Record 45 of Set 7 | kasongo-lunda
# Processing Record 46 of Set 7 | camargo
# Processing Record 47 of Set 7 | kokstad
# Processing Record 48 of Set 7 | smirnykh
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | oistins
# Processing Record 1 of Set 8 | shelburne
# Processing Record 2 of Set 8 | raudeberg
# Processing Record 3 of Set 8 | iracoubo
# Processing Record 4 of Set 8 | arcelia
# Processing Record 5 of Set 8 | egvekinot
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | parana
# Processing Record 8 of Set 8 | tocopilla
# Processing Record 9 of Set 8 | byron bay
# Processing Record 10 of Set 8 | tilichiki
# Processing Record 11 of Set 8 | cabrero
# Processing Record 12 of Set 8 | petrivka
# Processing Record 13 of Set 8 | caborca
# Processing Record 14 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | riyadh
# Processing Record 17 of Set 8 | ciudad bolivar
# Processing Record 18 of Set 8 | kismayo
# Processing Record 19 of Set 8 | sampit
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | voyvozh
# Processing Record 22 of Set 8 | kinkala
# Processing Record 23 of Set 8 | fredonia
# Processing Record 24 of Set 8 | shaartuz
# City not found. Skipping...
# Processing Record 25 of Set 8 | kalemie
# Processing Record 26 of Set 8 | along
# Processing Record 27 of Set 8 | road town
# Processing Record 28 of Set 8 | mogadishu
# Processing Record 29 of Set 8 | altamont
# Processing Record 30 of Set 8 | bani
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | jalu
# Processing Record 33 of Set 8 | angoche
# Processing Record 34 of Set 8 | maneadero
# Processing Record 35 of Set 8 | anori
# Processing Record 36 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 8 | san lorenzo
# Processing Record 38 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | kalmunai
# Processing Record 41 of Set 8 | iqaluit
# Processing Record 42 of Set 8 | santiago del estero
# Processing Record 43 of Set 8 | saint-paul
# Processing Record 44 of Set 8 | fare
# Processing Record 45 of Set 8 | whyalla
# Processing Record 46 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 8 | bengkulu
# Processing Record 48 of Set 8 | qeshm
# Processing Record 49 of Set 8 | meulaboh
# Processing Record 50 of Set 8 | ganzhou
# Processing Record 1 of Set 9 | broome
# Processing Record 2 of Set 9 | sechura
# Processing Record 3 of Set 9 | jardim
# Processing Record 4 of Set 9 | minnedosa
# Processing Record 5 of Set 9 | nome
# Processing Record 6 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 7 of Set 9 | hay river
# Processing Record 8 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | waddan
# Processing Record 11 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 9 | camana
# Processing Record 14 of Set 9 | spirit river
# Processing Record 15 of Set 9 | huaidian
# Processing Record 16 of Set 9 | souris
# Processing Record 17 of Set 9 | uruzgan
# Processing Record 18 of Set 9 | turayf
# Processing Record 19 of Set 9 | belyy yar
# Processing Record 20 of Set 9 | inta
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | yambio
# Processing Record 23 of Set 9 | san quintin
# Processing Record 24 of Set 9 | yangambi
# Processing Record 25 of Set 9 | berlevag
# Processing Record 26 of Set 9 | dwarka
# Processing Record 27 of Set 9 | zhifang
# Processing Record 28 of Set 9 | yashalta
# Processing Record 29 of Set 9 | zabaykalsk
# Processing Record 30 of Set 9 | madanapalle
# Processing Record 31 of Set 9 | hasaki
# Processing Record 32 of Set 9 | teknaf
# Processing Record 33 of Set 9 | rawson
# Processing Record 34 of Set 9 | wick
# Processing Record 35 of Set 9 | tinaquillo
# Processing Record 36 of Set 9 | jumla
# Processing Record 37 of Set 9 | barth
# Processing Record 38 of Set 9 | fukue
# Processing Record 39 of Set 9 | casper
# Processing Record 40 of Set 9 | kunya
# Processing Record 41 of Set 9 | ponta delgada
# Processing Record 42 of Set 9 | bridlington
# Processing Record 43 of Set 9 | makakilo city
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | gorontalo
# Processing Record 46 of Set 9 | chebenki
# Processing Record 47 of Set 9 | antofagasta
# Processing Record 48 of Set 9 | urosevac
# City not found. Skipping...
# Processing Record 49 of Set 9 | kudahuvadhoo
# Processing Record 50 of Set 9 | ostrovnoy
# Processing Record 1 of Set 10 | zanesville
# Processing Record 2 of Set 10 | mount isa
# Processing Record 3 of Set 10 | kloulklubed
# Processing Record 4 of Set 10 | christchurch
# Processing Record 5 of Set 10 | ilmajoki
# Processing Record 6 of Set 10 | pemberton
# Processing Record 7 of Set 10 | joshimath
# Processing Record 8 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 10 of Set 10 | the valley
# Processing Record 11 of Set 10 | coruripe
# Processing Record 12 of Set 10 | lebu
# Processing Record 13 of Set 10 | penzance
# Processing Record 14 of Set 10 | grodkow
# Processing Record 15 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 10 | susanville
# Processing Record 17 of Set 10 | nara
# Processing Record 18 of Set 10 | waipawa
# Processing Record 19 of Set 10 | poggibonsi
# Processing Record 20 of Set 10 | hammerfest
# Processing Record 21 of Set 10 | san blas
# Processing Record 22 of Set 10 | pedasi
# Processing Record 23 of Set 10 | papara
# Processing Record 24 of Set 10 | ust-kuyga
# Processing Record 25 of Set 10 | buraydah
# Processing Record 26 of Set 10 | linares
# Processing Record 27 of Set 10 | komsomolskiy
# Processing Record 28 of Set 10 | isla mujeres
# Processing Record 29 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 10 | nanakuli
# Processing Record 31 of Set 10 | bullingen
# City not found. Skipping...
# Processing Record 32 of Set 10 | vangaindrano
# Processing Record 33 of Set 10 | shabo
# Processing Record 34 of Set 10 | isiolo
# Processing Record 35 of Set 10 | kavieng
# Processing Record 36 of Set 10 | isoka
# Processing Record 37 of Set 10 | nizwa
# Processing Record 38 of Set 10 | alta floresta
# Processing Record 39 of Set 10 | floro
# Processing Record 40 of Set 10 | qinhuangdao
# Processing Record 41 of Set 10 | cidreira
# Processing Record 42 of Set 10 | araouane
# Processing Record 43 of Set 10 | vestmanna
# Processing Record 44 of Set 10 | trinidad
# Processing Record 45 of Set 10 | phalaborwa
# Processing Record 46 of Set 10 | sitio novo do tocantins
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | kabanjahe
# Processing Record 49 of Set 10 | baoshan
# Processing Record 50 of Set 10 | chernihiv
# Processing Record 1 of Set 11 | beringovskiy
# Processing Record 2 of Set 11 | bonavista
# Processing Record 3 of Set 11 | taltal
# Processing Record 4 of Set 11 | koindu
# Processing Record 5 of Set 11 | amahai
# Processing Record 6 of Set 11 | marystown
# Processing Record 7 of Set 11 | fairbanks
# Processing Record 8 of Set 11 | bom jesus
# Processing Record 9 of Set 11 | itamarandiba
# Processing Record 10 of Set 11 | naze
# Processing Record 11 of Set 11 | bardiyah
# Processing Record 12 of Set 11 | kotaparh
# Processing Record 13 of Set 11 | castelldefels
# Processing Record 14 of Set 11 | yian
# City not found. Skipping...
# Processing Record 15 of Set 11 | ubinskoye
# Processing Record 16 of Set 11 | khuzdar
# Processing Record 17 of Set 11 | nemuro
# Processing Record 18 of Set 11 | bosaso
# Processing Record 19 of Set 11 | sakakah
# Processing Record 20 of Set 11 | cotonou
# Processing Record 21 of Set 11 | rudiskes
# Processing Record 22 of Set 11 | bindura
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | ende
# Processing Record 25 of Set 11 | altay
# Processing Record 26 of Set 11 | cacapava do sul
# Processing Record 27 of Set 11 | zelenogradsk
# Processing Record 28 of Set 11 | mercedes
# Processing Record 29 of Set 11 | jatiroto
# Processing Record 30 of Set 11 | poum
# Processing Record 31 of Set 11 | faya
# Processing Record 32 of Set 11 | lesozavodsk
# Processing Record 33 of Set 11 | cantaura
# Processing Record 34 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 11 | la asuncion
# Processing Record 36 of Set 11 | pangnirtung
# Processing Record 37 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 11 | koulikoro
# Processing Record 39 of Set 11 | diego de almagro
# Processing Record 40 of Set 11 | capao bonito
# Processing Record 41 of Set 11 | djambala
# Processing Record 42 of Set 11 | inuvik
# Processing Record 43 of Set 11 | longyearbyen
# Processing Record 44 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 11 | gao
# Processing Record 46 of Set 11 | santa cruz de la palma
# Processing Record 47 of Set 11 | turukhansk
# Processing Record 48 of Set 11 | yashan
# Processing Record 49 of Set 11 | abha
# Processing Record 50 of Set 11 | sola
# Processing Record 1 of Set 12 | asau
# Processing Record 2 of Set 12 | saint-pierre
# Processing Record 3 of Set 12 | oranjemund
# Processing Record 4 of Set 12 | banda aceh
# Processing Record 5 of Set 12 | port hardy
# Processing Record 6 of Set 12 | otane
# Processing Record 7 of Set 12 | lafiagi
# Processing Record 8 of Set 12 | kailua
# Processing Record 9 of Set 12 | rio grande
# Processing Record 10 of Set 12 | buin
# Processing Record 11 of Set 12 | nago
# Processing Record 12 of Set 12 | bagan
# Processing Record 13 of Set 12 | avera
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | evensk
# Processing Record 16 of Set 12 | keuruu
# Processing Record 17 of Set 12 | sobolevo
# Processing Record 18 of Set 12 | jinxiang
# Processing Record 19 of Set 12 | chapais
# Processing Record 20 of Set 12 | manakara
# Processing Record 21 of Set 12 | nantucket
# Processing Record 22 of Set 12 | sabang
# Processing Record 23 of Set 12 | half moon bay
# Processing Record 24 of Set 12 | san vicente
# Processing Record 25 of Set 12 | bayir
# Processing Record 26 of Set 12 | sabha
# Processing Record 27 of Set 12 | alyangula
# Processing Record 28 of Set 12 | pareora
# Processing Record 29 of Set 12 | khipro
# Processing Record 30 of Set 12 | hudson bay
# Processing Record 31 of Set 12 | yangjiang
# Processing Record 32 of Set 12 | kampot
# Processing Record 33 of Set 12 | cape canaveral
# Processing Record 34 of Set 12 | pangai
# Processing Record 35 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 12 | cangucu
# Processing Record 37 of Set 12 | saint stephen
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | hargeysa
# Processing Record 40 of Set 12 | sur
# Processing Record 41 of Set 12 | isangel
# Processing Record 42 of Set 12 | khandyga
# Processing Record 43 of Set 12 | belogorsk
# Processing Record 44 of Set 12 | robertsport
# Processing Record 45 of Set 12 | havelock
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | panaba
# Processing Record 48 of Set 12 | dangriga
# Processing Record 49 of Set 12 | playa del carmen
# Processing Record 50 of Set 12 | paamiut
# Processing Record 1 of Set 13 | matara
# Processing Record 2 of Set 13 | atherton
# Processing Record 3 of Set 13 | aripuana
# Processing Record 4 of Set 13 | wuzhou
# Processing Record 5 of Set 13 | saint anthony
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create the dataframe with city data

# city_data is the dictionary we have with all the info. 

city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Deputatskiy  69.30  139.90     64.38        43          99        9.91
# 1         Ranong   9.97   98.63     84.20        83          75        4.70
# 2      Mahebourg -20.41   57.70     73.40        69          40        9.17
# 3  Kazachinskoye  57.70   93.28     56.48        62          17        3.85
# 4     Nikolskoye  59.70   30.79     79.00        50          75        8.95
#
#   Current Description  Snow (in)  Rain (in) Country                 Date
# 0     overcast clouds          0        0.0      RU  2020-06-16 13:26:02
# 1       broken clouds          0        0.0      TH  2020-06-16 13:26:02
# 2    scattered clouds          0        0.0      MU  2020-06-16 13:26:03
# 3          few clouds          0        0.0      RU  2020-06-16 13:26:03
# 4        thunderstorm          0        0.0      RU  2020-06-16 13:26:03

# %%
# reorder columns

column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain (in)","Snow (in)"]

city_data_df = city_data_df[column_order]

# 571 rows

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
