# %% [markdown]
# # Weather Database
# UC Berkeley Extension Data Analytics Boot Camp Module 6 Challenge - Part 1
#
# ## Part 1 Instructions
# #### Get the Weather Description and Amount of Precipitation for Each City

# %% [markdown]
# ### Collect the Data
# #### Use the NumPy module to generate more than 1,500 random latitudes and longitudes.

# %%
# Import Dependencies:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs) # packs each lat/lng pair into a tuple based on shared index

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Use the citipy module to list the nearest city to the latitudes and longitudes.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count (>500).
print(f"There are {len(cities)} cities in our database")
# Out:
# There are 624 cities in our database

# %% [markdown]
# #### Collect the following data from the JSON file and add it to a DataFrame:
#     - City, country, and date
#     - Latitude and longitude
#     - Maximum temperature
#     - Humidity
#     - Cloudiness
#     - Wind speed
#     - Weather Condition
#     - Snowfall (last 1 hr) - default to 0 if info is missing
#     - Rainfall (last 1 hr) - default to 0 if info is missing

# %%
# import the requests library
import requests

# import the API key from the config file
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# for farenheit, use units=imperial
# for celsius, use units=metric
# no units described will output in Kelvin

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# get a list that processes every name for validity (use try-except block)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        ### CHALLENGE:
        
        try:
            city_snow_1h = city_weather["snow"]["1h"]
        except KeyError: 
            city_snow_1h = 0
            
        try:
            city_rain_1h = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_1h = 0
            
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_desc,
                          "Snow (in)":city_snow_1h,
                          "Rain (in)":city_rain_1h,
                          "Country": city_country,
                          "Date": city_date})

#Use multiple try-except blocks to get the amount of rainfall and snowfall. 
#In the except block handle the KeyError if there is no rainfall or snowfall and add 0 inches for the amount.        
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | dovers
# Processing Record 3 of Set 1 | copiapo
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | malanje
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | hailin
# Processing Record 11 of Set 1 | xichang
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | tura
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | kalaiya
# Processing Record 17 of Set 1 | cururupu
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | grindavik
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | armidale
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | makakilo city
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | paamiut
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | kudahuvadhoo
# Processing Record 31 of Set 1 | nuuk
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | nabire
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | dickinson
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | kavaratti
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | batagay-alyta
# Processing Record 48 of Set 1 | los llanos de aridane
# Processing Record 49 of Set 1 | talnakh
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | iracoubo
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | touros
# Processing Record 8 of Set 2 | mehamn
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | vardo
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | ampanihy
# Processing Record 17 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | alice springs
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | basse-pointe
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | arman
# Processing Record 25 of Set 2 | pasighat
# Processing Record 26 of Set 2 | lazaro cardenas
# Processing Record 27 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | aswan
# Processing Record 30 of Set 2 | kilindoni
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | onega
# Processing Record 35 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | nouadhibou
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | murgab
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | auki
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | rio bueno
# Processing Record 48 of Set 2 | parana
# Processing Record 49 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 2 | colac
# Processing Record 1 of Set 3 | semey
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | beachwood
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | kununurra
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | karczew
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | jizan
# Processing Record 13 of Set 3 | burgeo
# Processing Record 14 of Set 3 | santa rosa
# Processing Record 15 of Set 3 | the valley
# Processing Record 16 of Set 3 | sioux lookout
# Processing Record 17 of Set 3 | camocim
# Processing Record 18 of Set 3 | daloa
# Processing Record 19 of Set 3 | naryan-mar
# Processing Record 20 of Set 3 | tete
# Processing Record 21 of Set 3 | decatur
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | inirida
# Processing Record 24 of Set 3 | healesville
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | namie
# Processing Record 30 of Set 3 | rawson
# Processing Record 31 of Set 3 | okha
# Processing Record 32 of Set 3 | laguna
# Processing Record 33 of Set 3 | cabedelo
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | baykit
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | zhangye
# Processing Record 38 of Set 3 | veraval
# Processing Record 39 of Set 3 | gainesville
# Processing Record 40 of Set 3 | hecun
# Processing Record 41 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | beringovskiy
# Processing Record 47 of Set 3 | namatanai
# Processing Record 48 of Set 3 | mandera
# Processing Record 49 of Set 3 | pacific grove
# Processing Record 50 of Set 3 | puerto ayacucho
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | tumpat
# Processing Record 4 of Set 4 | jasper
# Processing Record 5 of Set 4 | henderson
# Processing Record 6 of Set 4 | xuddur
# Processing Record 7 of Set 4 | barcelos
# Processing Record 8 of Set 4 | lanigan
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | puerto baquerizo moreno
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | xinqing
# Processing Record 13 of Set 4 | hornepayne
# Processing Record 14 of Set 4 | naisud
# Processing Record 15 of Set 4 | koryukivka
# Processing Record 16 of Set 4 | guarda
# Processing Record 17 of Set 4 | ca mau
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | diplo
# Processing Record 20 of Set 4 | keti bandar
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | rovaniemi
# Processing Record 23 of Set 4 | saint-raymond
# Processing Record 24 of Set 4 | napoleon
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 27 of Set 4 | zarya
# Processing Record 28 of Set 4 | mirassol
# Processing Record 29 of Set 4 | funadhoo
# Processing Record 30 of Set 4 | cockburn town
# Processing Record 31 of Set 4 | nakskov
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | venice
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | okhotsk
# Processing Record 36 of Set 4 | mabaruma
# Processing Record 37 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 38 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 4 | kerema
# Processing Record 40 of Set 4 | marawi
# Processing Record 41 of Set 4 | hovd
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | gayeri
# Processing Record 44 of Set 4 | coahuayana
# Processing Record 45 of Set 4 | jackson
# Processing Record 46 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 4 | paita
# Processing Record 48 of Set 4 | la libertad
# Processing Record 49 of Set 4 | dunedin
# Processing Record 50 of Set 4 | cocorit
# Processing Record 1 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 5 | isabela
# Processing Record 3 of Set 5 | panguna
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | vao
# Processing Record 7 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 5 | biak
# Processing Record 9 of Set 5 | ouallam
# Processing Record 10 of Set 5 | palmer
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | halifax
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | mugumu
# Processing Record 15 of Set 5 | solnechnyy
# Processing Record 16 of Set 5 | sorland
# Processing Record 17 of Set 5 | weihai
# Processing Record 18 of Set 5 | santa isabel do rio negro
# Processing Record 19 of Set 5 | manokwari
# Processing Record 20 of Set 5 | lahore
# Processing Record 21 of Set 5 | torbay
# Processing Record 22 of Set 5 | xingcheng
# Processing Record 23 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | sur
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | kapit
# Processing Record 28 of Set 5 | banff
# Processing Record 29 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 5 | sangar
# Processing Record 31 of Set 5 | adre
# Processing Record 32 of Set 5 | baker city
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | rongcheng
# Processing Record 35 of Set 5 | luganville
# Processing Record 36 of Set 5 | matagami
# Processing Record 37 of Set 5 | sept-iles
# Processing Record 38 of Set 5 | breves
# Processing Record 39 of Set 5 | bubaque
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | ankang
# Processing Record 44 of Set 5 | paide
# Processing Record 45 of Set 5 | ballina
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | kurumkan
# Processing Record 48 of Set 5 | oistins
# Processing Record 49 of Set 5 | bambous virieux
# Processing Record 50 of Set 5 | gigmoto
# Processing Record 1 of Set 6 | port hedland
# Processing Record 2 of Set 6 | buchanan
# Processing Record 3 of Set 6 | semirom
# Processing Record 4 of Set 6 | torrington
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | santa cruz
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | kupang
# Processing Record 9 of Set 6 | mogadishu
# Processing Record 10 of Set 6 | presidencia roque saenz pena
# Processing Record 11 of Set 6 | baindur
# Processing Record 12 of Set 6 | tarko-sale
# Processing Record 13 of Set 6 | thinadhoo
# Processing Record 14 of Set 6 | kalanguy
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | yuancheng
# Processing Record 17 of Set 6 | bull savanna
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | kamenka
# Processing Record 20 of Set 6 | buin
# Processing Record 21 of Set 6 | tateyama
# Processing Record 22 of Set 6 | baghdogra
# Processing Record 23 of Set 6 | gari
# Processing Record 24 of Set 6 | yambio
# Processing Record 25 of Set 6 | hays
# Processing Record 26 of Set 6 | khandyga
# Processing Record 27 of Set 6 | sakaiminato
# Processing Record 28 of Set 6 | bend
# Processing Record 29 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 6 | udachnyy
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | ledyard
# Processing Record 33 of Set 6 | verkhnyaya toyma
# Processing Record 34 of Set 6 | benjamin constant
# Processing Record 35 of Set 6 | sydney
# Processing Record 36 of Set 6 | nosy varika
# Processing Record 37 of Set 6 | itarema
# Processing Record 38 of Set 6 | margate
# Processing Record 39 of Set 6 | nanakuli
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | macaparana
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | corsicana
# Processing Record 44 of Set 6 | pristen
# Processing Record 45 of Set 6 | omboue
# Processing Record 46 of Set 6 | atar
# Processing Record 47 of Set 6 | mehriz
# Processing Record 48 of Set 6 | qaqortoq
# Processing Record 49 of Set 6 | lerma
# Processing Record 50 of Set 6 | shatrovo
# Processing Record 1 of Set 7 | chara
# Processing Record 2 of Set 7 | acarau
# Processing Record 3 of Set 7 | pontianak
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | ilhabela
# Processing Record 6 of Set 7 | samdrup jongkhar
# Processing Record 7 of Set 7 | clyde river
# Processing Record 8 of Set 7 | ishinomaki
# Processing Record 9 of Set 7 | kahului
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | kaitangata
# Processing Record 12 of Set 7 | pout
# Processing Record 13 of Set 7 | griffith
# Processing Record 14 of Set 7 | provideniya
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | bat khela
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | basco
# Processing Record 19 of Set 7 | ginda
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | zilair
# Processing Record 22 of Set 7 | vilhena
# Processing Record 23 of Set 7 | aloleng
# Processing Record 24 of Set 7 | dibombari
# Processing Record 25 of Set 7 | lata
# Processing Record 26 of Set 7 | port hardy
# Processing Record 27 of Set 7 | prince rupert
# Processing Record 28 of Set 7 | mount isa
# Processing Record 29 of Set 7 | ploemeur
# Processing Record 30 of Set 7 | irricana
# Processing Record 31 of Set 7 | richards bay
# Processing Record 32 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 7 | beloslav
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | texarkana
# Processing Record 38 of Set 7 | berlevag
# Processing Record 39 of Set 7 | merauke
# Processing Record 40 of Set 7 | quimperle
# Processing Record 41 of Set 7 | lima
# Processing Record 42 of Set 7 | saldanha
# Processing Record 43 of Set 7 | tuktoyaktuk
# Processing Record 44 of Set 7 | dingolfing
# Processing Record 45 of Set 7 | umm lajj
# Processing Record 46 of Set 7 | bonthe
# Processing Record 47 of Set 7 | astoria
# Processing Record 48 of Set 7 | warri
# Processing Record 49 of Set 7 | matara
# Processing Record 50 of Set 7 | angoche
# Processing Record 1 of Set 8 | acapulco
# Processing Record 2 of Set 8 | port-gentil
# Processing Record 3 of Set 8 | khatanga
# Processing Record 4 of Set 8 | ambilobe
# Processing Record 5 of Set 8 | salto
# Processing Record 6 of Set 8 | sunam
# Processing Record 7 of Set 8 | acari
# Processing Record 8 of Set 8 | evensk
# Processing Record 9 of Set 8 | aruppukkottai
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 8 | ishigaki
# Processing Record 13 of Set 8 | shache
# Processing Record 14 of Set 8 | axim
# Processing Record 15 of Set 8 | malpe
# Processing Record 16 of Set 8 | general pico
# Processing Record 17 of Set 8 | santa fe
# Processing Record 18 of Set 8 | kidal
# Processing Record 19 of Set 8 | morondava
# Processing Record 20 of Set 8 | kuryk
# Processing Record 21 of Set 8 | caala
# Processing Record 22 of Set 8 | mtwara
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | vestmanna
# Processing Record 26 of Set 8 | jining
# Processing Record 27 of Set 8 | manuk mangkaw
# Processing Record 28 of Set 8 | luderitz
# Processing Record 29 of Set 8 | maldonado
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | maroantsetra
# Processing Record 32 of Set 8 | piacabucu
# Processing Record 33 of Set 8 | tunceli
# Processing Record 34 of Set 8 | qasigiannguit
# Processing Record 35 of Set 8 | asosa
# Processing Record 36 of Set 8 | daru
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | grajau
# Processing Record 39 of Set 8 | strezhevoy
# Processing Record 40 of Set 8 | jalingo
# Processing Record 41 of Set 8 | rio claro
# Processing Record 42 of Set 8 | kremenki
# Processing Record 43 of Set 8 | ambikapur
# Processing Record 44 of Set 8 | kaohsiung
# Processing Record 45 of Set 8 | volzhsk
# Processing Record 46 of Set 8 | azanka
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | kjollefjord
# Processing Record 49 of Set 8 | kalengwa
# Processing Record 50 of Set 8 | waddan
# Processing Record 1 of Set 9 | brownfield
# Processing Record 2 of Set 9 | buala
# Processing Record 3 of Set 9 | aplahoue
# Processing Record 4 of Set 9 | whitehorse
# Processing Record 5 of Set 9 | san cristobal
# Processing Record 6 of Set 9 | fort-shevchenko
# Processing Record 7 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 9 | sabang
# Processing Record 9 of Set 9 | wanlaweyn
# Processing Record 10 of Set 9 | lakewood
# Processing Record 11 of Set 9 | gamba
# Processing Record 12 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 9 | yulara
# Processing Record 14 of Set 9 | bandar-e anzali
# Processing Record 15 of Set 9 | blackwater
# Processing Record 16 of Set 9 | nador
# Processing Record 17 of Set 9 | dalby
# Processing Record 18 of Set 9 | akyab
# Processing Record 19 of Set 9 | bukama
# Processing Record 20 of Set 9 | jamame
# Processing Record 21 of Set 9 | safranbolu
# Processing Record 22 of Set 9 | ranfurly
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 25 of Set 9 | lagos
# Processing Record 26 of Set 9 | darnah
# Processing Record 27 of Set 9 | coruripe
# Processing Record 28 of Set 9 | zlate moravce
# Processing Record 29 of Set 9 | bartlesville
# Processing Record 30 of Set 9 | seoul
# Processing Record 31 of Set 9 | kemijarvi
# Processing Record 32 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | kabinda
# Processing Record 35 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 9 | havoysund
# Processing Record 37 of Set 9 | luanda
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 9 | tchollire
# Processing Record 41 of Set 9 | komsomolskiy
# Processing Record 42 of Set 9 | castro
# Processing Record 43 of Set 9 | benghazi
# Processing Record 44 of Set 9 | jiuquan
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 9 | kurchum
# Processing Record 48 of Set 9 | kaeo
# Processing Record 49 of Set 9 | taoudenni
# Processing Record 50 of Set 9 | bileca
# Processing Record 1 of Set 10 | tromso
# Processing Record 2 of Set 10 | tazovskiy
# Processing Record 3 of Set 10 | henties bay
# Processing Record 4 of Set 10 | samandag
# Processing Record 5 of Set 10 | batemans bay
# Processing Record 6 of Set 10 | banjar
# Processing Record 7 of Set 10 | salalah
# Processing Record 8 of Set 10 | tawang
# Processing Record 9 of Set 10 | harbin
# Processing Record 10 of Set 10 | vila do maio
# Processing Record 11 of Set 10 | pizarro
# Processing Record 12 of Set 10 | gewane
# Processing Record 13 of Set 10 | kortkeros
# Processing Record 14 of Set 10 | ilebo
# Processing Record 15 of Set 10 | banda aceh
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | atlantic city
# Processing Record 18 of Set 10 | santa isabel
# Processing Record 19 of Set 10 | aguimes
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | dzhebariki-khaya
# Processing Record 22 of Set 10 | naron
# Processing Record 23 of Set 10 | amapa
# Processing Record 24 of Set 10 | caravelas
# Processing Record 25 of Set 10 | uruguaiana
# Processing Record 26 of Set 10 | muswellbrook
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | hay river
# Processing Record 29 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 10 | noboribetsu
# Processing Record 31 of Set 10 | luba
# Processing Record 32 of Set 10 | yeppoon
# Processing Record 33 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 10 | liyang
# Processing Record 35 of Set 10 | porbandar
# Processing Record 36 of Set 10 | dongsheng
# Processing Record 37 of Set 10 | cayenne
# Processing Record 38 of Set 10 | punto fijo
# Processing Record 39 of Set 10 | longyearbyen
# Processing Record 40 of Set 10 | neuquen
# Processing Record 41 of Set 10 | asbest
# Processing Record 42 of Set 10 | vanimo
# Processing Record 43 of Set 10 | saint-denis
# Processing Record 44 of Set 10 | port hawkesbury
# Processing Record 45 of Set 10 | kalnibolotskaya
# Processing Record 46 of Set 10 | kuytun
# Processing Record 47 of Set 10 | lander
# Processing Record 48 of Set 10 | pringsewu
# Processing Record 49 of Set 10 | kiama
# Processing Record 50 of Set 10 | hami
# Processing Record 1 of Set 11 | dukat
# Processing Record 2 of Set 11 | tikrit
# Processing Record 3 of Set 11 | vydrino
# Processing Record 4 of Set 11 | borogontsy
# Processing Record 5 of Set 11 | basoko
# Processing Record 6 of Set 11 | igrim
# Processing Record 7 of Set 11 | olinda
# Processing Record 8 of Set 11 | bandarbeyla
# Processing Record 9 of Set 11 | urumqi
# Processing Record 10 of Set 11 | hofn
# Processing Record 11 of Set 11 | kita
# Processing Record 12 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 11 | seddon
# Processing Record 14 of Set 11 | kiunga
# Processing Record 15 of Set 11 | goderich
# Processing Record 16 of Set 11 | batken
# Processing Record 17 of Set 11 | dudinka
# Processing Record 18 of Set 11 | kibala
# Processing Record 19 of Set 11 | kloulklubed
# Processing Record 20 of Set 11 | santa vitoria do palmar
# Processing Record 21 of Set 11 | nizhnevartovsk
# Processing Record 22 of Set 11 | loandjili
# Processing Record 23 of Set 11 | nouakchott
# Processing Record 24 of Set 11 | russell
# Processing Record 25 of Set 11 | owerri
# Processing Record 26 of Set 11 | mount gambier
# Processing Record 27 of Set 11 | santa luzia
# Processing Record 28 of Set 11 | am timan
# Processing Record 29 of Set 11 | katangli
# Processing Record 30 of Set 11 | srikakulam
# Processing Record 31 of Set 11 | baruun-urt
# Processing Record 32 of Set 11 | praia da vitoria
# Processing Record 33 of Set 11 | srednekolymsk
# Processing Record 34 of Set 11 | alto vera
# City not found. Skipping...
# Processing Record 35 of Set 11 | necochea
# Processing Record 36 of Set 11 | port macquarie
# Processing Record 37 of Set 11 | geraldton
# Processing Record 38 of Set 11 | kutum
# Processing Record 39 of Set 11 | adrar
# Processing Record 40 of Set 11 | lagoa
# Processing Record 41 of Set 11 | chicama
# Processing Record 42 of Set 11 | flin flon
# Processing Record 43 of Set 11 | kisangani
# Processing Record 44 of Set 11 | xiongzhou
# Processing Record 45 of Set 11 | rodrigues alves
# Processing Record 46 of Set 11 | bathsheba
# Processing Record 47 of Set 11 | chernenko
# Processing Record 48 of Set 11 | mackay
# Processing Record 49 of Set 11 | omsukchan
# Processing Record 50 of Set 11 | baculin
# Processing Record 1 of Set 12 | san pedro
# Processing Record 2 of Set 12 | ulenje
# Processing Record 3 of Set 12 | kalmunai
# Processing Record 4 of Set 12 | ipora
# Processing Record 5 of Set 12 | tongliao
# Processing Record 6 of Set 12 | talavera de la reina
# Processing Record 7 of Set 12 | ajaccio
# Processing Record 8 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 12 | dingle
# Processing Record 10 of Set 12 | yarada
# Processing Record 11 of Set 12 | vangaindrano
# Processing Record 12 of Set 12 | belmonte
# Processing Record 13 of Set 12 | san patricio
# Processing Record 14 of Set 12 | sao felix do xingu
# Processing Record 15 of Set 12 | murud
# Processing Record 16 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 12 | sola
# Processing Record 18 of Set 12 | gotsu
# Processing Record 19 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 20 of Set 12 | nago
# Processing Record 21 of Set 12 | libertador general san martin
# Processing Record 22 of Set 12 | jardim
# Processing Record 23 of Set 12 | tautira
# Processing Record 24 of Set 12 | krutinka
# Processing Record 25 of Set 12 | villazon
# Processing Record 26 of Set 12 | mapiripan
# Processing Record 27 of Set 12 | kurskaya
# Processing Record 28 of Set 12 | kumla
# Processing Record 29 of Set 12 | toora-khem
# Processing Record 30 of Set 12 | el dorado
# Processing Record 31 of Set 12 | puerto montt
# Processing Record 32 of Set 12 | manavalakurichi
# Processing Record 33 of Set 12 | atasu
# Processing Record 34 of Set 12 | port lincoln
# Processing Record 35 of Set 12 | severo-yeniseyskiy
# Processing Record 36 of Set 12 | sunrise manor
# Processing Record 37 of Set 12 | bambari
# Processing Record 38 of Set 12 | souris
# Processing Record 39 of Set 12 | ramanuj ganj
# Processing Record 40 of Set 12 | svetlogorsk
# Processing Record 41 of Set 12 | zwedru
# Processing Record 42 of Set 12 | mayo
# Processing Record 43 of Set 12 | tuatapere
# Processing Record 44 of Set 12 | soanierana ivongo
# Processing Record 45 of Set 12 | isangel
# Processing Record 46 of Set 12 | taos
# Processing Record 47 of Set 12 | ewa beach
# Processing Record 48 of Set 12 | ahipara
# Processing Record 49 of Set 12 | qui nhon
# Processing Record 50 of Set 12 | yei
# Processing Record 1 of Set 13 | sosua
# Processing Record 2 of Set 13 | kirakira
# Processing Record 3 of Set 13 | ueno
# Processing Record 4 of Set 13 | fort nelson
# Processing Record 5 of Set 13 | asfi
# Processing Record 6 of Set 13 | svetlaya
# Processing Record 7 of Set 13 | pachino
# Processing Record 8 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 13 | kargopol
# Processing Record 10 of Set 13 | saint-pierre
# Processing Record 11 of Set 13 | jalu
# Processing Record 12 of Set 13 | sungurlu
# Processing Record 13 of Set 13 | lenger
# Processing Record 14 of Set 13 | shelburne
# Processing Record 15 of Set 13 | bagula
# Processing Record 16 of Set 13 | hualmay
# Processing Record 17 of Set 13 | salme
# Processing Record 18 of Set 13 | carauari
# Processing Record 19 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 13 | arlit
# Processing Record 21 of Set 13 | galiakot
# Processing Record 22 of Set 13 | ondjiva
# Processing Record 23 of Set 13 | straumen
# Processing Record 24 of Set 13 | arnissa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create the dataframe with city data

# city_data is the dictionary we have with all the info. 

city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#       City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bluff -46.60  168.33     54.39        75          63       15.05
# 1   Dovers  12.88  -61.18     84.20        70          75       11.41
# 2  Copiapo -27.37  -70.33     55.40        76          90        6.93
# 3  Malanje  -9.54   16.34     78.80        54          40       12.75
# 4    Airai  -8.93  125.41     57.97       100          27        4.47
#
#   Current Description  Snow (in)  Rain (in) Country                 Date
# 0       broken clouds          0        0.0      NZ  2020-06-16 13:26:24
# 1       broken clouds          0        0.0      VC  2020-06-16 13:34:59
# 2     overcast clouds          0        0.0      CL  2020-06-16 13:34:59
# 3    scattered clouds          0        0.0      AO  2020-06-16 13:26:41
# 4    scattered clouds          0        0.0      TL  2020-06-16 13:26:29

# %%
# reorder columns

column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain (in)","Snow (in)"]

city_data_df = city_data_df[column_order]

# 571 rows

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
