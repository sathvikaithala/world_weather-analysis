# %% [markdown]
# # Weather Database
# UC Berkeley Extension Data Analytics Boot Camp Module 6 Challenge - Part 1
#
# ## Part 1 Instructions
# #### Get the Weather Description and Amount of Precipitation for Each City

# %% [markdown]
# ### Collect the Data
# #### Use the NumPy module to generate more than 1,500 random latitudes and longitudes.

# %%
# Import Dependencies:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs) # packs each lat/lng pair into a tuple based on shared index

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Use the citipy module to list the nearest city to the latitudes and longitudes.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count (>500).
print(f"There are {len(cities)} cities in our database")
# Out:
# There are 625 cities in our database

# %% [markdown]
# #### Collect the following data from the JSON file and add it to a DataFrame:
#     - City, country, and date
#     - Latitude and longitude
#     - Maximum temperature
#     - Humidity
#     - Cloudiness
#     - Wind speed
#     - Weather Condition
#     - Snowfall (last 1 hr) - default to 0 if info is missing
#     - Rainfall (last 1 hr) - default to 0 if info is missing

# %%
# import the requests library
import requests

# import the API key from the config file
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# for farenheit, use units=imperial
# for celsius, use units=metric
# no units described will output in Kelvin

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# get a list that processes every name for validity (use try-except block)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        ### CHALLENGE:
        
        try:
            city_snow_1h = city_weather["snow"]["1h"]
        except KeyError: 
            city_snow_1h = 0
            
        try:
            city_rain_1h = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_1h = 0
            
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description":city_desc,
                          "Snow (in)":city_snow_1h,
                          "Rain (in)":city_rain_1h,
                          "Country": city_country,
                          "Date": city_date})

#Use multiple try-except blocks to get the amount of rainfall and snowfall. 
#In the except block handle the KeyError if there is no rainfall or snowfall and add 0 inches for the amount.        
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | luganville
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | half moon bay
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | goderich
# Processing Record 9 of Set 1 | san andres
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | khovu-aksy
# Processing Record 14 of Set 1 | monrovia
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | nelson bay
# Processing Record 17 of Set 1 | melfi
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | constitucion
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | santa maria
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | tamarindo
# Processing Record 28 of Set 1 | padang
# Processing Record 29 of Set 1 | jibuti
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | pombas
# Processing Record 32 of Set 1 | clearwater
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | smithers
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | kearney
# Processing Record 45 of Set 1 | tena
# Processing Record 46 of Set 1 | raudeberg
# Processing Record 47 of Set 1 | port-gentil
# Processing Record 48 of Set 1 | vila velha
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | lekoni
# Processing Record 1 of Set 2 | beni mazar
# Processing Record 2 of Set 2 | laguna de perlas
# Processing Record 3 of Set 2 | soure
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | santiago del estero
# Processing Record 8 of Set 2 | husavik
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | shizukuishi
# Processing Record 11 of Set 2 | abha
# Processing Record 12 of Set 2 | bubaque
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | progress
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | dalvik
# Processing Record 17 of Set 2 | kuva
# City not found. Skipping...
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | moree
# Processing Record 24 of Set 2 | corn island
# Processing Record 25 of Set 2 | dwarka
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | quechultenango
# Processing Record 29 of Set 2 | velyka bilozerka
# Processing Record 30 of Set 2 | tomatlan
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | hauterive
# Processing Record 33 of Set 2 | lafia
# Processing Record 34 of Set 2 | vilyuysk
# Processing Record 35 of Set 2 | sorel
# Processing Record 36 of Set 2 | lahij
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | buala
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | manavalakurichi
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | gouyave
# Processing Record 45 of Set 2 | juba
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | port blair
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | lermontovka
# Processing Record 3 of Set 3 | normandin
# Processing Record 4 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 3 | takoradi
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | mascote
# Processing Record 8 of Set 3 | sabang
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | manzanillo
# Processing Record 11 of Set 3 | berlevag
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | samarai
# Processing Record 14 of Set 3 | suleja
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | ikwiriri
# Processing Record 17 of Set 3 | carupano
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | hovd
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | aranjuez
# Processing Record 22 of Set 3 | iskateley
# Processing Record 23 of Set 3 | lagoa
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | ordzhonikidze
# Processing Record 26 of Set 3 | jalu
# Processing Record 27 of Set 3 | labuhan
# Processing Record 28 of Set 3 | gongzhuling
# Processing Record 29 of Set 3 | nelson
# Processing Record 30 of Set 3 | qorveh
# Processing Record 31 of Set 3 | ambilobe
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | rumoi
# Processing Record 37 of Set 3 | saint-louis
# Processing Record 38 of Set 3 | tutoia
# Processing Record 39 of Set 3 | tadine
# Processing Record 40 of Set 3 | zhigansk
# Processing Record 41 of Set 3 | hidalgo
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | noshiro
# Processing Record 44 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | bereda
# Processing Record 47 of Set 3 | busselton
# Processing Record 48 of Set 3 | ixtapa
# Processing Record 49 of Set 3 | saint anthony
# Processing Record 50 of Set 3 | hobart
# Processing Record 1 of Set 4 | alta floresta
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | natal
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | porbandar
# Processing Record 6 of Set 4 | jojoima
# Processing Record 7 of Set 4 | aksu
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | renqiu
# Processing Record 10 of Set 4 | ewo
# Processing Record 11 of Set 4 | port-cartier
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | tekkali
# Processing Record 14 of Set 4 | san cristobal
# Processing Record 15 of Set 4 | margate
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | mpika
# Processing Record 18 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 4 | guder
# Processing Record 20 of Set 4 | kharan
# Processing Record 21 of Set 4 | tabas
# Processing Record 22 of Set 4 | qui nhon
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | muros
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | takaka
# Processing Record 27 of Set 4 | beboto
# Processing Record 28 of Set 4 | tarauaca
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | peno
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | meiganga
# Processing Record 36 of Set 4 | glubokoe
# City not found. Skipping...
# Processing Record 37 of Set 4 | kamenka
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | bredasdorp
# Processing Record 40 of Set 4 | spearfish
# Processing Record 41 of Set 4 | chapais
# Processing Record 42 of Set 4 | ust-tsilma
# Processing Record 43 of Set 4 | kapaa
# Processing Record 44 of Set 4 | cherskiy
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | waddan
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | kawalu
# Processing Record 49 of Set 4 | nardaran
# Processing Record 50 of Set 4 | balsas
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | biak
# Processing Record 3 of Set 5 | port lincoln
# Processing Record 4 of Set 5 | bundaberg
# Processing Record 5 of Set 5 | tuy hoa
# Processing Record 6 of Set 5 | guerrero negro
# Processing Record 7 of Set 5 | itumba
# Processing Record 8 of Set 5 | terneuzen
# Processing Record 9 of Set 5 | hudson bay
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | acapulco
# Processing Record 12 of Set 5 | mikuni
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | korla
# Processing Record 17 of Set 5 | tateyama
# Processing Record 18 of Set 5 | bowen
# Processing Record 19 of Set 5 | kentau
# Processing Record 20 of Set 5 | beringovskiy
# Processing Record 21 of Set 5 | nikolskoye
# Processing Record 22 of Set 5 | oksfjord
# Processing Record 23 of Set 5 | shimoda
# Processing Record 24 of Set 5 | kyshtovka
# Processing Record 25 of Set 5 | grindavik
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | mamontovo
# Processing Record 28 of Set 5 | kailua
# Processing Record 29 of Set 5 | jumla
# Processing Record 30 of Set 5 | canar
# Processing Record 31 of Set 5 | yar-sale
# Processing Record 32 of Set 5 | san julian
# Processing Record 33 of Set 5 | dovers
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | yellowknife
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | zaplyusye
# City not found. Skipping...
# Processing Record 40 of Set 5 | sanming
# Processing Record 41 of Set 5 | lodja
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | luderitz
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 47 of Set 5 | port alfred
# Processing Record 48 of Set 5 | nehe
# Processing Record 49 of Set 5 | mixtepec
# City not found. Skipping...
# Processing Record 50 of Set 5 | chivay
# Processing Record 1 of Set 6 | ye
# City not found. Skipping...
# Processing Record 2 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 6 | sri aman
# Processing Record 4 of Set 6 | chumikan
# Processing Record 5 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 6 | richards bay
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | hoi an
# Processing Record 9 of Set 6 | hithadhoo
# Processing Record 10 of Set 6 | oranjemund
# Processing Record 11 of Set 6 | praia
# Processing Record 12 of Set 6 | kaeo
# Processing Record 13 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 6 | toppenish
# Processing Record 15 of Set 6 | mirnyy
# Processing Record 16 of Set 6 | necochea
# Processing Record 17 of Set 6 | bambous virieux
# Processing Record 18 of Set 6 | pimentel
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | klyuchi
# Processing Record 21 of Set 6 | lenine
# Processing Record 22 of Set 6 | gawler
# Processing Record 23 of Set 6 | kijabe
# Processing Record 24 of Set 6 | zhuhai
# Processing Record 25 of Set 6 | christchurch
# Processing Record 26 of Set 6 | kushmurun
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | praia da vitoria
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | hemsedal
# Processing Record 31 of Set 6 | quelimane
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | pueblo nuevo
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | phillipsburg
# Processing Record 37 of Set 6 | namatanai
# Processing Record 38 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 6 | guiyang
# Processing Record 40 of Set 6 | bowmore
# Processing Record 41 of Set 6 | hachinohe
# Processing Record 42 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 6 | carmarthen
# Processing Record 44 of Set 6 | doha
# Processing Record 45 of Set 6 | provideniya
# Processing Record 46 of Set 6 | varhaug
# Processing Record 47 of Set 6 | maniitsoq
# Processing Record 48 of Set 6 | quatre cocos
# Processing Record 49 of Set 6 | adrar
# Processing Record 50 of Set 6 | sturgeon bay
# Processing Record 1 of Set 7 | nago
# Processing Record 2 of Set 7 | kahului
# Processing Record 3 of Set 7 | ngunguru
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | stepnyak
# Processing Record 6 of Set 7 | abu samrah
# Processing Record 7 of Set 7 | hengshui
# Processing Record 8 of Set 7 | dalnegorsk
# Processing Record 9 of Set 7 | tessalit
# Processing Record 10 of Set 7 | obidos
# Processing Record 11 of Set 7 | wajid
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | nhulunbuy
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | garissa
# Processing Record 16 of Set 7 | polunochnoye
# Processing Record 17 of Set 7 | bushehr
# Processing Record 18 of Set 7 | yulara
# Processing Record 19 of Set 7 | port hardy
# Processing Record 20 of Set 7 | igarka
# Processing Record 21 of Set 7 | grandview
# Processing Record 22 of Set 7 | central point
# Processing Record 23 of Set 7 | ballinrobe
# Processing Record 24 of Set 7 | havre-saint-pierre
# Processing Record 25 of Set 7 | machilipatnam
# Processing Record 26 of Set 7 | port arthur
# Processing Record 27 of Set 7 | kenai
# Processing Record 28 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 7 | nurota
# Processing Record 30 of Set 7 | buraydah
# Processing Record 31 of Set 7 | huambo
# Processing Record 32 of Set 7 | dunmore town
# Processing Record 33 of Set 7 | le port
# Processing Record 34 of Set 7 | vao
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | sao filipe
# Processing Record 38 of Set 7 | mayo
# Processing Record 39 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 7 | brigantine
# Processing Record 41 of Set 7 | huanren
# Processing Record 42 of Set 7 | campoverde
# Processing Record 43 of Set 7 | kota kinabalu
# Processing Record 44 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 7 | pailon
# Processing Record 46 of Set 7 | hervey bay
# Processing Record 47 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 7 | inuvik
# Processing Record 49 of Set 7 | meulaboh
# Processing Record 50 of Set 7 | caldwell
# Processing Record 1 of Set 8 | khuzhir
# Processing Record 2 of Set 8 | roald
# Processing Record 3 of Set 8 | vanavara
# Processing Record 4 of Set 8 | taikang
# Processing Record 5 of Set 8 | hennenman
# Processing Record 6 of Set 8 | saskylakh
# Processing Record 7 of Set 8 | agadir
# Processing Record 8 of Set 8 | brody
# Processing Record 9 of Set 8 | upata
# Processing Record 10 of Set 8 | karratha
# Processing Record 11 of Set 8 | mbaiki
# Processing Record 12 of Set 8 | selma
# Processing Record 13 of Set 8 | kiama
# Processing Record 14 of Set 8 | yingcheng
# Processing Record 15 of Set 8 | bengkulu
# Processing Record 16 of Set 8 | taoudenni
# Processing Record 17 of Set 8 | kloulklubed
# Processing Record 18 of Set 8 | georgetown
# Processing Record 19 of Set 8 | huron
# Processing Record 20 of Set 8 | changji
# Processing Record 21 of Set 8 | khor
# Processing Record 22 of Set 8 | nanortalik
# Processing Record 23 of Set 8 | krasnyy chikoy
# Processing Record 24 of Set 8 | alyangula
# Processing Record 25 of Set 8 | ahipara
# Processing Record 26 of Set 8 | wa
# City not found. Skipping...
# Processing Record 27 of Set 8 | tugalan
# City not found. Skipping...
# Processing Record 28 of Set 8 | antofagasta
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 8 | longkou
# Processing Record 31 of Set 8 | gubkinskiy
# Processing Record 32 of Set 8 | diamantino
# Processing Record 33 of Set 8 | teeli
# Processing Record 34 of Set 8 | kourou
# Processing Record 35 of Set 8 | toora-khem
# Processing Record 36 of Set 8 | kurchum
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | wasilla
# Processing Record 40 of Set 8 | itarema
# Processing Record 41 of Set 8 | mount gambier
# Processing Record 42 of Set 8 | gashua
# Processing Record 43 of Set 8 | mortka
# Processing Record 44 of Set 8 | almeirim
# Processing Record 45 of Set 8 | windsor
# Processing Record 46 of Set 8 | puerto colombia
# Processing Record 47 of Set 8 | pithiviers
# Processing Record 48 of Set 8 | zastron
# Processing Record 49 of Set 8 | aksarka
# Processing Record 50 of Set 8 | nioro
# Processing Record 1 of Set 9 | dickinson
# Processing Record 2 of Set 9 | novoorsk
# Processing Record 3 of Set 9 | dehloran
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | faanui
# Processing Record 6 of Set 9 | xixiang
# Processing Record 7 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 9 | dongying
# Processing Record 9 of Set 9 | kirakira
# Processing Record 10 of Set 9 | wanderlandia
# City not found. Skipping...
# Processing Record 11 of Set 9 | abtenau
# Processing Record 12 of Set 9 | ketou
# Processing Record 13 of Set 9 | murud
# Processing Record 14 of Set 9 | florianopolis
# Processing Record 15 of Set 9 | alice springs
# Processing Record 16 of Set 9 | bilma
# Processing Record 17 of Set 9 | bafoulabe
# Processing Record 18 of Set 9 | kongolo
# Processing Record 19 of Set 9 | george
# Processing Record 20 of Set 9 | kununurra
# Processing Record 21 of Set 9 | abalak
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | alekseyevsk
# Processing Record 24 of Set 9 | hobyo
# Processing Record 25 of Set 9 | lichtenburg
# Processing Record 26 of Set 9 | black river
# Processing Record 27 of Set 9 | formosa do rio preto
# Processing Record 28 of Set 9 | taree
# Processing Record 29 of Set 9 | doctor arroyo
# Processing Record 30 of Set 9 | babusnica
# Processing Record 31 of Set 9 | mizan teferi
# Processing Record 32 of Set 9 | bolgatanga
# Processing Record 33 of Set 9 | conde
# Processing Record 34 of Set 9 | puerto leguizamo
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 9 | bang saphan
# Processing Record 38 of Set 9 | forio
# Processing Record 39 of Set 9 | majene
# Processing Record 40 of Set 9 | codrington
# Processing Record 41 of Set 9 | kavaratti
# Processing Record 42 of Set 9 | birobidzhan
# Processing Record 43 of Set 9 | boa vista
# Processing Record 44 of Set 9 | sao joao da barra
# Processing Record 45 of Set 9 | chaoyang
# Processing Record 46 of Set 9 | langsa
# Processing Record 47 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 9 | geraldton
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | lingao
# Processing Record 1 of Set 10 | rosarito
# Processing Record 2 of Set 10 | gwadar
# Processing Record 3 of Set 10 | hat yai
# Processing Record 4 of Set 10 | tornio
# Processing Record 5 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 6 of Set 10 | shahpura
# Processing Record 7 of Set 10 | bayan
# Processing Record 8 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 10 | puerto del rosario
# Processing Record 10 of Set 10 | goma
# Processing Record 11 of Set 10 | charters towers
# Processing Record 12 of Set 10 | leningradskiy
# Processing Record 13 of Set 10 | catamarca
# Processing Record 14 of Set 10 | paramonga
# Processing Record 15 of Set 10 | mabaruma
# Processing Record 16 of Set 10 | baisha
# Processing Record 17 of Set 10 | moerai
# Processing Record 18 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 10 | bamnet narong
# Processing Record 20 of Set 10 | gallup
# Processing Record 21 of Set 10 | siniscola
# Processing Record 22 of Set 10 | manggar
# Processing Record 23 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 24 of Set 10 | saint george
# Processing Record 25 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 10 | sandnessjoen
# Processing Record 27 of Set 10 | sibu
# Processing Record 28 of Set 10 | terney
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | acarau
# Processing Record 31 of Set 10 | asau
# Processing Record 32 of Set 10 | road town
# Processing Record 33 of Set 10 | san policarpo
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 36 of Set 10 | shenyang
# Processing Record 37 of Set 10 | clonakilty
# Processing Record 38 of Set 10 | salinopolis
# Processing Record 39 of Set 10 | aklavik
# Processing Record 40 of Set 10 | malakal
# Processing Record 41 of Set 10 | paamiut
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | rio grande
# Processing Record 44 of Set 10 | ommen
# Processing Record 45 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 10 | tazovskiy
# Processing Record 47 of Set 10 | labuan
# Processing Record 48 of Set 10 | buseresere
# Processing Record 49 of Set 10 | elko
# Processing Record 50 of Set 10 | marchena
# Processing Record 1 of Set 11 | vila franca do campo
# Processing Record 2 of Set 11 | kevsala
# Processing Record 3 of Set 11 | stornoway
# Processing Record 4 of Set 11 | ulaangom
# Processing Record 5 of Set 11 | zabid
# Processing Record 6 of Set 11 | inyonga
# Processing Record 7 of Set 11 | tanout
# Processing Record 8 of Set 11 | san ramon
# Processing Record 9 of Set 11 | gazanjyk
# Processing Record 10 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | aliwal north
# Processing Record 12 of Set 11 | himora
# City not found. Skipping...
# Processing Record 13 of Set 11 | sisimiut
# Processing Record 14 of Set 11 | emporia
# Processing Record 15 of Set 11 | atar
# Processing Record 16 of Set 11 | karasjok
# Processing Record 17 of Set 11 | chino valley
# Processing Record 18 of Set 11 | saint-joseph
# Processing Record 19 of Set 11 | komsomolskiy
# Processing Record 20 of Set 11 | fort-shevchenko
# Processing Record 21 of Set 11 | xining
# Processing Record 22 of Set 11 | ordino
# Processing Record 23 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 24 of Set 11 | yangmei
# Processing Record 25 of Set 11 | beira
# Processing Record 26 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 27 of Set 11 | letterkenny
# Processing Record 28 of Set 11 | batouri
# Processing Record 29 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 11 | wooster
# Processing Record 31 of Set 11 | grand gaube
# Processing Record 32 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 11 | macau
# Processing Record 34 of Set 11 | namibe
# Processing Record 35 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 11 | emerald
# Processing Record 37 of Set 11 | sambava
# Processing Record 38 of Set 11 | berdigestyakh
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | auki
# Processing Record 41 of Set 11 | rochester
# Processing Record 42 of Set 11 | vostok
# Processing Record 43 of Set 11 | nisia floresta
# Processing Record 44 of Set 11 | baruun-urt
# Processing Record 45 of Set 11 | cap malheureux
# Processing Record 46 of Set 11 | itapetinga
# Processing Record 47 of Set 11 | dalbandin
# Processing Record 48 of Set 11 | harper
# Processing Record 49 of Set 11 | port moresby
# Processing Record 50 of Set 11 | norden
# Processing Record 1 of Set 12 | novyy urgal
# Processing Record 2 of Set 12 | bonthe
# Processing Record 3 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 12 | plouzane
# Processing Record 6 of Set 12 | canico
# Processing Record 7 of Set 12 | inhambane
# Processing Record 8 of Set 12 | mandera
# Processing Record 9 of Set 12 | deputatskiy
# Processing Record 10 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 12 of Set 12 | yebaishou
# Processing Record 13 of Set 12 | porto real
# Processing Record 14 of Set 12 | saint-esteve
# Processing Record 15 of Set 12 | puerto escondido
# Processing Record 16 of Set 12 | rovaniemi
# Processing Record 17 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 12 | xuchang
# Processing Record 19 of Set 12 | auka
# Processing Record 20 of Set 12 | bulgan
# Processing Record 21 of Set 12 | laukaa
# Processing Record 22 of Set 12 | anloga
# Processing Record 23 of Set 12 | sao gabriel da cachoeira
# Processing Record 24 of Set 12 | maun
# Processing Record 25 of Set 12 | kupang
# Processing Record 26 of Set 12 | sur
# Processing Record 27 of Set 12 | grafton
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | vangaindrano
# Processing Record 30 of Set 12 | port hedland
# Processing Record 31 of Set 12 | manicore
# Processing Record 32 of Set 12 | ca mau
# Processing Record 33 of Set 12 | mitu
# Processing Record 34 of Set 12 | carpentras
# Processing Record 35 of Set 12 | hotaka
# Processing Record 36 of Set 12 | xuddur
# Processing Record 37 of Set 12 | bakel
# Processing Record 38 of Set 12 | ewa beach
# Processing Record 39 of Set 12 | palaikastron
# Processing Record 40 of Set 12 | korablino
# Processing Record 41 of Set 12 | storforshei
# Processing Record 42 of Set 12 | gasa
# Processing Record 43 of Set 12 | broken hill
# Processing Record 44 of Set 12 | krasnaya gorbatka
# Processing Record 45 of Set 12 | jinka
# Processing Record 46 of Set 12 | san marcos
# Processing Record 47 of Set 12 | pringsewu
# Processing Record 48 of Set 12 | mackay
# Processing Record 49 of Set 12 | angoche
# Processing Record 50 of Set 12 | bathsheba
# Processing Record 1 of Set 13 | ukiah
# Processing Record 2 of Set 13 | qujing
# Processing Record 3 of Set 13 | pilar
# Processing Record 4 of Set 13 | amarante do maranhao
# Processing Record 5 of Set 13 | samut prakan
# Processing Record 6 of Set 13 | druzhba
# Processing Record 7 of Set 13 | verkhnyaya inta
# Processing Record 8 of Set 13 | yurkivka
# Processing Record 9 of Set 13 | launceston
# Processing Record 10 of Set 13 | noumea
# Processing Record 11 of Set 13 | coihaique
# Processing Record 12 of Set 13 | greenville
# Processing Record 13 of Set 13 | nkowakowa
# Processing Record 14 of Set 13 | marsh harbour
# Processing Record 15 of Set 13 | lere
# Processing Record 16 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 13 | altay
# Processing Record 18 of Set 13 | miri
# Processing Record 19 of Set 13 | hazorasp
# Processing Record 20 of Set 13 | san juan del sur
# Processing Record 21 of Set 13 | benghazi
# Processing Record 22 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 23 of Set 13 | khlung
# Processing Record 24 of Set 13 | bose
# Processing Record 25 of Set 13 | gainesville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create the dataframe with city data

# city_data is the dictionary we have with all the info. 

city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Avarua -21.21 -159.78     71.60        68           8        6.93
# 1      Esperance -33.87  121.90     57.20        62          33       10.29
# 2     Luganville -15.53  167.17     78.80        83          20       11.41
# 3        Rikitea -23.12 -134.97     75.07        81          55       10.42
# 4  Half Moon Bay  37.46 -122.43     55.99        87           1       18.34
#
#   Weather Description  Snow (in)  Rain (in) Country                 Date
# 0           clear sky        0.0        0.0      CK  2020-06-16 13:10:05
# 1    scattered clouds        0.0        0.0      AU  2020-06-16 13:12:13
# 2          few clouds        0.0        0.0      VU  2020-06-16 13:12:13
# 3       broken clouds        0.0        0.0      PF  2020-06-16 13:12:14
# 4                mist        0.0        0.0      US  2020-06-16 13:12:14

# %%
# reorder columns

column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description","Rain (in)","Snow (in)"]

city_data_df = city_data_df[column_order]

# 571 rows

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
